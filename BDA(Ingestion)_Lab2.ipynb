# %%
import pandas as pd
df = pd.read_csv('airport.csv')

class Airport:
    def __init__(self, country, user_name = ''):
        self.country = country
        self.user_name = user_name
    
    def read(self):
        print(df)

    def search(self):
        print(df.loc[:, ['name', 'city', 'country', 'iata_code']])
    
    def countryy(self):
        print(df[df['country'] == self.country].loc[:, ['name', 'city']])
    
    def user_info(self):
        count = df[df['country'] == self.country].loc[:, 'name'].count()
        f = open('user_info.txt', 'w')
        summ = self.user_name + ',' + self.country + ',' + str(count)
        f.write(summ)
        f.close()
        
def choose(x):
    if x == 1:
        a1.read()
    elif x == 2:
        a1.search()
    elif x == 3:
        a1.countryy()
    elif x == 4:
        a1.countryy()
    elif x == 5:
        a1.user_info()
    
a1 = Airport('Kazakhstan', 'Arlan')
x = -1
while x != 0:
    print('\n==============================MENU=================================')
    print('1. Reader')
    print('2. Save info: name, city, country, iata_code')
    print('3. 3a) Search for country')
    print('4. 3b) Return the list of airport names at this country with its city')
    print('5. Save user info to "user_info.txt"')
    print('\n===================================================================')
    x = int(input("Choose:"))
    choose(x)
# Out:
# ==============================MENU=================================
# 1. Reader
# 2. Save info: name, city, country, iata_code
# 3. 3a) Search for country
# 4. 3b) Return the list of airport names at this country with its city
# 5. Save user info to "user_info.txt"
#
# ...
# Choose:0

# %%
df
# Out:
#                                   name     city           country iata_code  \
# 0      Hartsfield Jackson Atlanta Intl  Atlanta     United States       ATL
# 1                   Chicago Ohare Intl  Chicago     United States       ORD
# 2                         Capital Intl  Beijing             China       PEK
# 3                             Heathrow   London    United Kingdom       LHR
# 4                    Charles De Gaulle    Paris            France       CDG
# ...                                ...      ...               ...       ...
# 3277                      Massawa Intl  Massawa           Eritrea       MSW
# 3278  Teniente Coronel Luis A Mantilla   Tulcan           Ecuador       TUA
# 3279                              Ovda     Ovda            Israel       VDA
# 3280                          Filippos   Kozani            Greece       KZI
# 3281                           Kalemie  Kalemie  Congo (Kinshasa)       FMI
#
# ...
