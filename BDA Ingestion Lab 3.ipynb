# %%
# Task 1
import pandas as pd
col_list = ['Date', 'High', 'Low']
df = pd.read_csv('GOOG.csv', usecols = col_list)
df
# Out:
#            Date         High          Low
# 0    2020-02-10  1509.500000  1474.319946
# 1    2020-02-11  1529.630005  1505.637939
# 2    2020-02-12  1520.694946  1508.109985
# 3    2020-02-13  1527.180054  1504.599976
# 4    2020-02-14  1520.739990  1507.339966
# ..          ...          ...          ...
# 248  2021-02-03  2116.500000  2018.380005
# 249  2021-02-04  2078.550049  2042.589966
# 250  2021-02-05  2102.510010  2059.330078
# 251  2021-02-08  2123.547119  2072.000000
# 252  2021-02-09  2104.949951  2078.540039
#
# [253 rows x 3 columns]

# %%
# Task 2
import numpy as np
arr = np.array(df)
arr
# Out:
# array([['2020-02-10', 1509.5, 1474.319946],
#        ['2020-02-11', 1529.630005, 1505.637939],
#        ['2020-02-12', 1520.694946, 1508.109985],
#        ['2020-02-13', 1527.180054, 1504.599976],
#        ['2020-02-14', 1520.73999, 1507.339966],
#        ['2020-02-18', 1531.630005, 1512.589966],
#        ['2020-02-19', 1532.105957, 1521.400024],
#        ['2020-02-20', 1529.640015, 1506.819946],
#        ['2020-02-21', 1512.214966, 1480.439941],
#        ['2020-02-24', 1436.969971, 1411.390015],
#        ['2020-02-25', 1438.140015, 1382.400024],
#        ['2020-02-26', 1415.699951, 1379.0],
#        ['2020-02-27', 1371.703979, 1317.170044],
#        ['2020-02-28', 1341.140015, 1271.0],
#        ['2020-03-02', 1390.869995, 1326.814941],
#        ['2020-03-03', 1410.150024, 1332.0],
#        ['2020-03-04', 1388.089966, 1343.109985],
#        ['2020-03-05', 1358.910034, 1305.099976],
#        ['2020-03-06', 1306.219971, 1261.050049],
#        ['2020-03-09', 1254.76001, 1200.0],
# ...

# %%
# Task 3
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(df['Date'], df['High'])
plt.title('Date and High price')
plt.xlabel('Date')
plt.ylabel('High Price')
# Out:
# Text(0, 0.5, 'High Price')

# %%
# Task 4
plt.plot(df['Date'], df['Low'], 'r--')
plt.title('Date and Low price')
plt.xlabel('Date')
plt.ylabel('Low price')
plt.show()

# %%
# Task 5
fig = plt.figure()
ax = fig.add_subplot(111)
ax.fill_between(df['Date'], df['Low'], df['High'])

# %%
# Task 6
fig1 = plt.figure()

axes1 = fig1.add_axes([0.1, 0.1, 0.8, 0.8]) 
axes2 = fig1.add_axes([0.2, 0.5, 0.4, 0.3])
axes3 = fig1.add_axes([0.3, 0.2, 0.3, 0.2])

# %%
# Task 7
fig1.savefig('Task 6, lab 3.png')
